# %% [markdown]
# # Set up environment

# %%
from dotenv import load_dotenv

load_dotenv(override=True)

# %%
import os


OPENSEARCH_USERNAME = os.environ["OPENSEARCH_USERNAME"]
OPENSEARCH_PASSWORD = os.environ["OPENSEARCH_PASSWORD"]
OPENSEARCH_URL = os.environ["OPENSEARCH_URL"]
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# # Useful functions

# %%
from opensearchpy import OpenSearch
import ollama
from ollama import Client
import requests


# Scrape and URL loader
from utils.sfc_look_up import extract_table, headers

# Opensearch
from opensearchpy.exceptions import RequestError, NotFoundError
import pdfplumber
from typing import Optional
import io
from tqdm import tqdm
import string


def get_open_search(cluster_url: str, username: str, password: str):

    client = OpenSearch(
        hosts=[cluster_url], http_auth=(username, password), verify_certs=False
    )
    return client


def get_embedding(text: str, embedding_model: str) -> list[float]:
    response = ollama_client.embeddings(
        model=EMBEDDING_MODEL,
        prompt=text,
    )
    return response["embedding"]


def create_index(
    index_name: str, embedding_dim: int, force_create: bool = False
) -> bool:
    """Create a Opensearch new index.

    Args:
        index_name (str): Index name
        embedding_dim (int): Dimension of the embedding vector
        exists_ok (bool): Force create new index if it already exists
    Raises:
        Request: Error if index creation fails

    Returns:
        bool: Create succeeded
    """

    try:
        open_search_client.indices.delete(index_name)
    except NotFoundError:
        pass

    index_body = {
        "settings": {"index": {"knn": True, "knn.algo_param.ef_search": 100}},
        "mappings": {  # how do we store,
            "properties": {
                "embedding": {
                    "type": "knn_vector",  # we are going to put
                    "dimension": embedding_dim,
                    "method": {
                        "name": "hnsw",
                        "space_type": "l2",
                        "engine": "nmslib",
                        "parameters": {"ef_construction": 128, "m": 24},
                    },
                }
            }
        },
    }
    try:
        response = open_search_client.indices.create(index=index_name, body=index_body)
    except RequestError as re:
        error_notice = re.args[1]
        if error_notice != "resource_already_exists_exception":
            raise e
        elif not force_create:
            raise e
        print(f"Index {index_name} already exists")
    return True


def read_pdf_given_url(url: str) -> pdfplumber.pdf.PDF:
    """Read PDF file from an accessible URL"""
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    iostream = io.BytesIO()
    iostream.write(response.content)
    return pdfplumber.open(iostream)

# %% [markdown]
# # Set up clients

# %%
open_search_client: OpenSearch = get_open_search(
    OPENSEARCH_URL, OPENSEARCH_USERNAME, OPENSEARCH_PASSWORD
)
ollama_client: ollama.Client = Client(host="http://localhost:11434")

# %% [markdown]
# # Configable parameters

# %%
EMBEDDING_MODEL = "all-minilm"  # Better for KNN
# EMBEDDING_MODEL = "mxbai-embed-large" 
EMBEDDING_DIM = len(
    get_embedding("Llamas are members of the camelid family", EMBEDDING_MODEL)
)
PREPROCESS = False
INDEX_NAME = "sfc_code" + "_preprocess"*PREPROCESS
CHUNK_SIZE = 1024
MINIMUM_TEXT_LENGTH_PER_PAGE = 32
MINIMUM_WORD_COUNT_PER_PAGE = 16

# %%
print(INDEX_NAME)

# %% [markdown]
# # Data ingestion

# %%
create_result = create_index(INDEX_NAME, EMBEDDING_DIM, force_create=True)
if create_result:
    print(f"Successfully create a new index {INDEX_NAME}")

print("Scrape PDF files")
table_of_contents = extract_table()


def skip(text: str) -> bool:
    """Skips if match condition.
    Args:
        text (str): Input text
    Returns:
        bool: If match
    """
    if len(text) < MINIMUM_TEXT_LENGTH_PER_PAGE:
        return True
    if len(text.split()) < MINIMUM_WORD_COUNT_PER_PAGE:
        return True
    if "This page is intended to be blank" in text:
        return True

def preprocess_text(text: str) -> str:
    text = text.replace("  "," ").replace("  "," ")
    text = text.replace("\n\n","\n").replace("\n\n","\n")
    for special_character in string.punctuation:
        text.replace(special_character, "")
    return text

print("Start ingestion")
for content in tqdm(table_of_contents):
    # Extract metadata
    topic_title = content["title"]
    file_url = content["url"]

    # Read file
    pdf = read_pdf_given_url(file_url)

    # Extract pdf data
    for page in pdf.pages:
        page_number = page.page_number
        text = page.extract_text_simple()
        if PREPROCESS:
            text = preprocess_text(text)
        if skip(text):
            continue
        start = 0
        end = CHUNK_SIZE
        text_length = len(text)
        chunk_count = text_length // CHUNK_SIZE
        for chunk_index, start in enumerate(range(0, text_length, CHUNK_SIZE)):
            end = start + CHUNK_SIZE
            chunk_text = text[start:end].strip()
            if not chunk_text:
                continue

            embedding = get_embedding(chunk_text, EMBEDDING_MODEL)
            doc = {
                "file_url": file_url,
                "topic_title": topic_title,
                "page_number": page_number,
                "chunk_index": chunk_index,
                "text": chunk_text,
                "embedding": embedding,
            }
            res = open_search_client.index(
                index=INDEX_NAME,
                body=doc,
                id=f"{topic_title}_{page_number}_{chunk_index}",
                refresh=True,
            )
# Out:
# Successfully create a new index sfc_code
# Scrape PDF files
# Start ingestion
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [03:05<00:00, 12.35s/it]

# %%
user_query = "Share Buy-backs condition"


query_embedding = get_embedding(user_query, EMBEDDING_MODEL)


query_body = {
    "query": {
        "bool": {
            "must": [
                {"knn": {"embedding": {"vector": query_embedding, "k": 50}}},
                #                 {
                #                     "match": {
                #                         "text": {
                #                             "query": user_query,
                #                         },
                #                     }
                #                 },
                {
                    "match": {
                        "topic_title": {
                            "query": "The Codes on Takeovers and Mergers and Share Buy-backs",
                        },
                    }
                },
            ]
        }
    },
    "_source": False,
    "fields": ["id", "topic_title", "text", "file_url"],
}

results = open_search_client.search(body=query_body, index=INDEX_NAME)



open_search_client.search(body=query_body, index=INDEX_NAME)
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 176, 'relation': 'eq'},
#   'max_score': 10.819632,
#   'hits': [{'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_185_0',
#     '_score': 10.819632,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['RULE 32 \n32.   Share buy-backs  \n32.1   Code implications of share buy-backs  \nIf as a result of a share buy-back a shareholder’s proportionate interest in the voting \nrights of  the  repurchasing company increases, such increase will be treated as an \nacquisition of voting rights for purposes of the Takeovers Code. As a result, a shareholder, \nor group of shareholders acting in concert, could obtain or consolidate control of a \nrepurchasing  company  and  thereby  become  obliged  to  make  a  mandatory  offer  in \naccordance  with  Rule  26.  If  so  the  Executive  should  be  consulted  at  the  earliest \nopportunity. In the case of a share buy-back by general offer or an off-market share \nbuy-back, as such terms are defined in the Codes, the Executive will treat an application \nfor a waiver from the requirement to make a mandatory offer in accordance with Rule 26 \nas  if  it  were  an  application  for  a  whitewash  waiver  in  accordance  with  Note  1  on \ndispensations from Rule 26. The Executive wil']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_199_0',
#     '_score': 10.819279,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['RULE 1 \n1.   Methods of share buy-back  \nA company may only engage in the following types of share buy-back:–  \n(a)   an on-market share buy-back;  \n(b)   an off-market share buy-back approved in accordance with Rule 2;  \n(c)   an exempt share buy-back; and  \n(d)   a share buy-back by general offer in accordance with the General Principles and \nRules of the Codes.  \nA share buy-back may normally be made only by the company the shares of which are the \nsubject of the share buy-back. Where a wholly owned subsidiary of a company has issued \nsecurities exercisable or convertible into shares of that company such subsidiary may \nredeem or buy-back such securities in accordance with the terms of their issue. \nSeptember 2023  SBC-1.1']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_197_0',
#     '_score': 10.818794,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['CODE ON SHARE BUY-BACKS \nCONTENTS \nRules   Page \n1.   Methods of share buy-back  SBC-1.1 \n2.   Off-market share buy-backs  SBC-2.1 \n3.   Shareholder approval  SBC-3.1 \n4.   The offer document   SBC-4.1 \n5.  Application of the Takeovers Code to share buy-backs  SBC-5.1 \n6.  Takeovers Code implications of share buy-backs  SBC-6.1 \n7.   Prohibition on distributions  SBC-7.1 \n8.   Waivers  SBC-8.1 \nSeptember 2023']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_243_1',
#     '_score': 10.818783,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['share buy-back (as the case may be) in accordance with the Codes; or  \n(iii)   where the relevant shares are under the offer or the off-market share \nbuy-back (as the case may be) to be acquired partly for cash and partly \nin exchange for securities, the aggregate of the total amount of such \ncash and the total value of such securities on the date of announcement \nof a firm intention to make the offer or the off-market share buy-back (as \nthe case may be) in accordance with the Codes; and  \n(b)   the value of a whitewashed offer in the case of a whitewash document shall \nbe–  \n(i)   where the relevant shares would under such whitewashed offer be \nacquired for cash, the total amount of such cash;  \n(ii)   where the relevant shares would under such whitewashed offer be \nacquired in exchange for securities, the total value of such securities on \nthe  date  of  announcement  of  a  firm  intention  to  enter  into  the \ntransaction which would require such whitewashed offer to be made in \nthe absence of a waive']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_213_0',
#     '_score': 10.818682,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['RULE 8 \n8.   Waivers  \nThe  Executive  has  discretion  to  waive  compliance  with  requirements  of  the  Share \nBuy-backs Code particularly if any party to a share buy-back considers that compliance \nwould be unduly burdensome, e.g. in the case of a share buy-back by general offer to odd \nlot shareholders or a share buy-back by general offer for non-voting fixed participation \nshares which are more analogous to debt securities than equity securities. \n \nSeptember 2023  SBC-8.1']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_208_1',
#     '_score': 10.818598,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['me proportion as the \nnumber tendered to the extent necessary to enable the offeror to obtain the total number \nof shares for which the offer has been made.  \n5.4   On-market share buy-backs  \nAn  offeror  shall  not  engage  in  an  on-market  share  buy-back  after  the  date  of  the \nannouncement of a share buy-back by general offer up to and including the date share \nbuy-back by general offer closes, lapses or is withdrawn, as the case may be.  \nSBC-5.2  September 2023']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_208_0',
#     '_score': 10.818503,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['RULE 5 \nNote to Rule 5.1:  \nNotes to Rules of the Takeovers Code  \nIn the case of a number of the Rules of the Takeovers Code listed above in this Rule 5.1 \nthat may be applicable to share buy-backs by general offer some of the Notes to such \nRules may not be relevant and the Executive should be consulted.  \n5.2   Excluded shareholders  \nWhere an offeror has shareholders located in a jurisdiction the laws of which prohibit a \nshare buy-back by general offer to be made in accordance with the requirements of the \nCodes, the Executive must be consulted. The Executive will be concerned to ensure that \nthe interests of such shareholders are not unduly prejudiced.  \n5.3   Pro rata entitlement  \nShare buy-backs by general offer must be made to all shareholders of the class and \narrangements must be made for those shareholders who wish to do so to accept in full for \nthe relevant percentage of their holdings. Shares tendered in excess of this percentage \nmust be accepted by the offeror from each shareholder in the sa']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_251_3',
#     '_score': 10.818438,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['btain the prior authorisation of its shareholders for a proposed share \nbuy-back if the proposed share buy-back constituted an off-market share buy-back for a \nsmall number of shares of the company from a shareholder who was not a director, chief \nSeptember 2023  Sch V-3']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_237_0',
#     '_score': 10.818098,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['SCHEDULE III \n7.  Assuming the offer is successful, the effect which the offer will have on the percentage \nvoting rights of the persons referred to in paragraph 5 of this Schedule III.  \nTerms of the share buy-back  \n8.  The reasons for the proposed share buy-back and for the number of shares proposed to \nbe bought back.  \n9.  The pro rating and odd lot procedures of the offer.  \nShares offered for and dividends  \n10.   Particulars of the class and number of shares to be bought back and a statement as to \nwhether the shares to be bought back are to be acquired cum or ex any dividend or other \ndistribution which has been or may be declared.  \nConditions of offer  \n11.   The consideration to be offered for the shares.  \n12.   All  conditions  of  the  offer  and  in  particular  whether  the  offer  is  conditional  upon \nacceptances being received in respect of a minimum number and the last day on which \nthe offer can become unconditional as to acceptances. The offer document must include \nparticulars of all']}},
#    {'_index': 'sfc_code',
#     '_id': 'The Codes on Takeovers and Mergers and Share Buy-backs_251_2',
#     '_score': 10.818029,
#     'fields': {'file_url': ['https://www.sfc.hk/-/media/EN/assets/components/codes/files-current/web/codes/the-codes-on-takeovers-and-mergers-and-share-buy-backs/English-TO-Code-20230928-FINAL.pdf?rev=ce39f30e56784e6ea97fd512e1bfc9cd'],
#      'topic_title': ['The Codes on Takeovers and Mergers and Share Buy-backs'],
#      'text': ['o be made by way of an \non-market share buy-back conducted in accordance with the Listing Rules.  \n5.0  Specific exemptions  \n5.1   A specific exemption is intended to relieve a particular listed company from one or more of \nthe share buy-back requirements of sections 238, 239 or 240 of the Ordinance. It is \ncurrently anticipated that three types of specific exemptions would be granted.  \n5.2   The first type of specific exemption would relieve an applicant from the requirement to \nobtain the prior authorisation of its shareholders for a proposed share buy-back if a \ndisorderly market for the shares of the company had developed, or was reasonably \nexpected to develop, and time did not permit a shareholder’s meeting to be held. Such an \nexemption would normally be conditional upon the share buy-back being made by way of \nan on-market share buy-back conducted in accordance with the Listing Rules.  \n5.3   The  second  type  of  specific  exemption  would  also  relieve  an  applicant  from  the \nrequirement to o']}}]}}
